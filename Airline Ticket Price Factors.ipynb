# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels
import matplotlib.pyplot as plt
import math

## Preview Table Data
flight = pd.read_csv("flight.csv")
print(flight.head())
# Out:
#    ID  miles  passengers  delay inflight_meal inflight_entertainment  \
# 0   1    792         172      0            No                    Yes
# 1   2   3163         214      0            No                    Yes
# 2   3   1832         212      0            No                    Yes
# 3   4    925         213      0            No                    Yes
# 4   5    967         217      0           Yes                    Yes
#
#   inflight_wifi day_of_week redeye weekend  coach_price  firstclass_price  \
# 0           Yes      Sunday    Yes     Yes      338.820           1571.02
# 1           Yes      Sunday     No     Yes      472.655           1663.70
# 2            No      Friday     No     Yes      351.960           1429.86
# 3           Yes    Saturday     No     Yes      387.835           1558.76
# 4           Yes      Monday     No      No      374.735           1245.58
#
#    hours
# 0      1
# 1      6
# 2      3
# 3      2
# 4      2

# %%
## Summary Stats re:coach ticket prices
print('The max coach ticket price was: $' + str(round(flight.coach_price.max(),2)))
print('The min coach ticket price was: $' + str(round(flight.coach_price.min(),2)))
print('The mean coach ticket price was: $' + str(round(flight.coach_price.mean(),2)))
# Out:
# The max coach ticket price was: $593.63
# The min coach ticket price was: $44.41
# The mean coach ticket price was: $376.59

# %%
##coach price distribution
sns.histplot(flight.coach_price)
# Out:
# <Axes: xlabel='coach_price', ylabel='Count'>

# %%
#prices related to ammenities

# Inflight Meals
sns.histplot(flight, x = "coach_price", hue = flight.inflight_meal)
plt.show()
plt.clf()

# Inflight Entertainment
sns.histplot(flight, x = "coach_price", hue = flight.inflight_entertainment)
plt.show()
plt.clf()

# Inflight WiFi
sns.histplot(flight, x = "coach_price", hue = flight.inflight_wifi)
plt.show()
plt.clf()

# %%
## weekday vs. weekend
sns.histplot(flight, x = "coach_price", hue = 'weekend')
plt.show()
plt.clf()
